# %% [markdown]
# # Feature Scaling:
# - ### nature remains same
# - ### magnitude degrades
#
#
# ## Types of feature scaling:
# - ### Standardization
# - ### Normalization

# %% [markdown]
# ## Standardization :
#
# Effective technique to re-scale a feature value so that it has distibution with 0 mean value and variance equals to 1
#
#
# $X_{new} = (X_i - X_{mean})/\text{Standard Deviation}$

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv('data/titanic.csv')

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
dataset["Age"] = dataset["Age"].fillna(dataset["Age"].mean())

# %%
dataset["Age"].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.distplot(dataset["Age"])
plt.show()
# Out:
# C:\Users\taksh\AppData\Local\Temp\ipykernel_23176\3953522691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Age"])

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()

# %%
ss.fit(dataset[["Age"]])
# Out:
# StandardScaler()

# %%
dataset["Age_ss"] = pd.DataFrame(ss.transform(dataset[["Age"]]), columns=["x"])

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Age_ss
# 0      0         A/5 21171   7.2500   NaN        S -0.592481
# 1      0          PC 17599  71.2833   C85        C  0.638789
# 2      0  STON/O2. 3101282   7.9250   NaN        S -0.284663
# 3      0            113803  53.1000  C123        S  0.407926
# ...

# %%
dataset.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare        Age_ss
# count  891.000000  891.000000  8.910000e+02
# mean     0.381594   32.204208  2.232906e-16
# std      0.806057   49.693429  1.000562e+00
# min      0.000000    0.000000 -2.253155e+00
# 25%      0.000000    7.910400 -5.924806e-01
# 50%      0.000000   14.454200  0.000000e+00
# 75%      0.000000   31.000000  4.079260e-01
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,2)
plt.title("After")
sns.distplot(x = dataset["Age_ss"])
plt.subplot(1,2,1)
plt.title("Before")
sns.distplot(dataset["Age"])
plt.show()
# Out:
# C:\Users\taksh\AppData\Local\Temp\ipykernel_23176\2412303885.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset["Age_ss"])
# C:\Users\taksh\AppData\Local\Temp\ipykernel_23176\2412303885.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # Feature Scaling - Normalization
#
# Normalization :
#
# values range up inbetween 0 and 1. (Min-Max scaling)
#
# $X_{new} = (X_i - min(X))/(max(X) - min(X))$

# %%
dataset = dataset.drop(columns=["Age_ss"])

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dataset["Age"].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
sns.distplot(dataset["Age"])
plt.show()
# Out:
# C:\Users\taksh\AppData\Local\Temp\ipykernel_23176\3953522691.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset["Age"])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
ms = MinMaxScaler()
ms.fit(dataset[["Age"]])
# Out:
# MinMaxScaler()

# %%
dataset["Age_ms"] = ms.transform(dataset[["Age"]])

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked    Age_ms
# 0      0         A/5 21171   7.2500   NaN        S  0.271174
# 1      0          PC 17599  71.2833   C85        C  0.472229
# 2      0  STON/O2. 3101282   7.9250   NaN        S  0.321438
# 3      0            113803  53.1000  C123        S  0.434531
# ...

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,2)
plt.title("After")
sns.distplot(x = dataset["Age_ms"])
plt.subplot(1,2,1)
plt.title("Before")
sns.distplot(dataset["Age"])
plt.show()
# Out:
# C:\Users\taksh\AppData\Local\Temp\ipykernel_23176\987594786.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x = dataset["Age_ms"])
# C:\Users\taksh\AppData\Local\Temp\ipykernel_23176\987594786.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
