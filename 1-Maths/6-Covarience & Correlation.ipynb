# %% [markdown]
# # Covarience:
#
# - #### the direction of the linear relationship between the two variable
#
# $\text{Cov}(X, Y) = \frac{1}{n}\sum_{i=1}^{n}(x_i - \bar{x})(y_i - \bar{y})$
#
# - ##### X increase -> Y increase = Positive Correlation
# - ##### X increase -> Y decrease = Negative Correlation
# - ##### X and Y are independent = Zero Correlation
#
# - #### limit -> -Infinite to Infinity (Observation is hard)
#
#
# # Correlation:
#
# - #### limit -> -1 to 1 (Easy to observe)
# - ###### Higher the absolute value of Correlation -> Higher the data is related to each other
#
# $\rho_{X,Y} = \frac{\text{Cov}(X,Y)}{\sigma_X \sigma_Y}$
#
# - #### $\text{Cov}(X,Y)$ -> Covariance
# - #### $\sigma_X$ -> STD of X
# - #### $\sigma_Y$ -> STD of Y

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv('data/tips.csv')

# %%
dataset.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458

# %%
dataset.isnull().sum()
# Out:
# total_bill          0
# tip                 0
# sex                 0
# smoker              0
# day                 0
# time                0
# size                0
# price_per_person    0
# Payer Name          0
# CC Number           0
# Payment ID          0
# dtype: int64

# %%
dataset.drop(["price_per_person", "Payer Name", "CC Number", "Payment ID"], axis = 1, inplace=True)

# %%
dataset.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
data_cov = dataset.select_dtypes(["float64", "int64"]).cov()
data_cov
# Out:
#             total_bill       tip      size
# total_bill   79.252939  8.323502  5.065983
# tip           8.323502  1.914455  0.643906
# size          5.065983  0.643906  0.904591

# %%
data_corr = dataset.select_dtypes(["float64", "int64"]).corr()
data_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(4,3))
sns.heatmap(data_corr, annot=True)
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.heatmap(data_cov, annot=True)
plt.show()
